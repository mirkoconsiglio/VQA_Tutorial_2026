# %%
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import efficient_su2
from qiskit.quantum_info import SparsePauliOp, Statevector

# optimizer imports
from qiskit_algorithms.optimizers import *

# Plotting functions
import matplotlib.pyplot as plt

from functools import partial

# Global dictionary
cost_history_dict = {
	"prev_vector": None,
	"iters": 0,
	"cost_history": [],
}

from qiskit_ibm_runtime import EstimatorV2 as Estimator

# We will run everything on a local simulator. To run on real hardware you would
# instead pick a backend from QiskitRuntimeService and wrap the calls in a Session.
from qiskit_aer import AerSimulator
backend = AerSimulator()

# %% [markdown]
# ## Hamiltonian
#
# Our next two components: the PQC and measurement strategy, may depend quite a bit on our Hamiltonian, and any constraints which we wish to satisfy (however for the sake of simplicity we will suppose that we have no extra constraints). However, for now we shall take statevector simulations, that is we assume that we have perfect information of the quantum state (we have access to its vector representation). Thus, we need not worry about the measurement technique yet. This is useful for prototyping your VQA, ensuring that everything works.
#
# We shall take a simplified $H_2$ model at $0.735$Å, which can be written in Qiskit as
#
# > **Note.** This operator is a toy: it has roughly the right coefficient magnitudes for hydrogen but it is not the molecular Hamiltonian, so its lowest eigenvalue is not a physical energy. We derive the real one in `3_Chemistry.ipynb`.

# %%
hamiltonian = SparsePauliOp.from_list(
    [("YZ", 0.3980), ("ZI", -0.3980), ("ZZ", -0.0113), ("XX", 0.1810)]
)

# %% [markdown]
# ## Parameterized quantum circuit
#
# Now let's proceed to use a simple two local ansatz, that is an ansatz which alternates between parameterized one-qubit gates, and (non-parameterized) two-qubit entangling gates

# %%
ansatz = efficient_su2(hamiltonian.num_qubits)
ansatz.draw("mpl", style="iqp")

# %% [markdown]
# ## Preparing for Quantum Execution
#
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).
#
# ISA circuit Schedule a series of `qiskit.transpiler` passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
# In principle, this code is not needed unless we intend to run it on a quantum device
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %% [markdown]
# ## ISA observable
#
# Transform the Hamiltonian to make it backend-compatible before running jobs with `Runtime Estimator V2`. Perform the transformation by using the apply_layout method of SparsePauliOp object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# $$\newcommand{\ket}[1]{\left|{#1}\right\rangle}$$
# $$\newcommand{\bra}[1]{\left\langle{#1}\right|}$$
#
# # Variational Quantum Eigensolver
#
# The VQE is the first type of hybrid quantum--classical which was proposed, and it is the first one we will deal with. The cost function in this case based on the Ritz variational principle, that is
#
# \begin{equation}
#     C(\boldsymbol{\theta}) = \bra{\psi(\boldsymbol{\theta})}\mathcal{H}\ket{\psi(\boldsymbol{\theta})}.
# \end{equation}
#
# The minimum of this function is the ground-state energy:
#
# \begin{equation}
#     E_0 = \min_{\boldsymbol{\theta}}\bra{\psi(\boldsymbol{\theta})}\mathcal{H}\ket{\psi(\boldsymbol{\theta})}.
# \end{equation}
#
# We thus have the first component of our VQA, the cost function.
#
# With the Qiskit Runtime `Estimator` directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of Qiskit Runtime `EstimatorV2` takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_function(params, ansatz, hamiltonian, estimator):
	pub = (ansatz, [hamiltonian], [params])
	result = estimator.run(pubs=[pub]).result()
	energy = result[0].data.evs[0]
	
	cost_history_dict["iters"] += 1
	cost_history_dict["prev_vector"] = params
	cost_history_dict["cost_history"].append(energy)
	print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")
	
	return energy

# %% [markdown]
# ## Classical optimizer
#
# As we said, for now shall focus on statevector simulations and not worry about measurements. The next step is then choose a classical optimizer. Qiskit has many optimizers to choose from. Quite a bit of them are based on Scipy's implementations. We will take the COBYLA optimizer for the time being.

# %%
optimizer = COBYLA()

# %% [markdown]
# ## Putting it all together
#
# We now just need to run the algorithm optimizing through to get our ground-state energy

# %%
x0 = np.random.uniform(-np.pi, np.pi, len(ansatz.parameters))  # We need an initial point (which can be random)

estimator = Estimator(mode=backend)
estimator.options.default_shots = 10000

wrapped_cost_function = partial(cost_function, ansatz=ansatz_isa, hamiltonian=hamiltonian_isa, estimator=estimator)
result = optimizer.minimize(fun=wrapped_cost_function, x0=x0)

print(result)
# Out:
# Iters. done: 1 [Current cost: 0.03547310000000001]
# Iters. done: 2 [Current cost: -0.34539038]
# Iters. done: 3 [Current cost: -0.3255692]
# Iters. done: 4 [Current cost: -0.25708476]
# Iters. done: 5 [Current cost: -0.25578886]
# Iters. done: 6 [Current cost: -0.29025774]
# Iters. done: 7 [Current cost: -0.15042324]
# Iters. done: 8 [Current cost: -0.35763380000000006]
# Iters. done: 9 [Current cost: -0.17411468000000002]
# Iters. done: 10 [Current cost: -0.31829064]
# Iters. done: 11 [Current cost: -0.33206904000000004]
# Iters. done: 12 [Current cost: -0.24171518000000003]
# Iters. done: 13 [Current cost: -0.40870304]
# Iters. done: 14 [Current cost: -0.48972794]
# Iters. done: 15 [Current cost: -0.37061330000000003]
# Iters. done: 16 [Current cost: -0.39098726000000006]
# Iters. done: 17 [Current cost: -0.43368042]
# Iters. done: 18 [Current cost: -0.5404329200000001]
# Iters. done: 19 [Current cost: -0.5144647400000001]
# Iters. done: 20 [Current cost: -0.5018853600000001]
# Iters. done: 21 [Current cost: -0.42879580000000006]
# Iters. done: 22 [Current cost: -0.56123812]
# Iters. done: 23 [Current cost: -0.4938847]
# Iters. done: 24 [Current cost: -0.5590879799999999]
# Iters. done: 25 [Current cost: -0.56788112]
# Iters. done: 26 [Current cost: -0.45352594000000007]
# Iters. done: 27 [Current cost: -0.55324552]
# Iters. done: 28 [Current cost: -0.34892182000000005]
# Iters. done: 29 [Current cost: -0.59185314]
# Iters. done: 30 [Current cost: -0.62740318]
# Iters. done: 31 [Current cost: -0.32126802]
# Iters. done: 32 [Current cost: -0.5725851200000001]
# Iters. done: 33 [Current cost: -0.40039981999999996]
# Iters. done: 34 [Current cost: -0.6046568]
# Iters. done: 35 [Current cost: -0.6635834600000001]
# Iters. done: 36 [Current cost: -0.44367716]
# Iters. done: 37 [Current cost: -0.58138216]
# Iters. done: 38 [Current cost: -0.50206548]
# Iters. done: 39 [Current cost: -0.5820238799999999]
# Iters. done: 40 [Current cost: -0.34161858]
# Iters. done: 41 [Current cost: -0.64463528]
# Iters. done: 42 [Current cost: -0.45359398000000006]
# Iters. done: 43 [Current cost: -0.6109741200000001]
# Iters. done: 44 [Current cost: -0.43246574]
# Iters. done: 45 [Current cost: -0.6520992800000001]
# Iters. done: 46 [Current cost: -0.44855454000000006]
# Iters. done: 47 [Current cost: -0.6206062]
# Iters. done: 48 [Current cost: -0.39964382000000004]
# Iters. done: 49 [Current cost: -0.62622862]
# Iters. done: 50 [Current cost: -0.50345944]
# Iters. done: 51 [Current cost: -0.5771185200000001]
# Iters. done: 52 [Current cost: -0.65515476]
# Iters. done: 53 [Current cost: -0.6322340799999999]
# Iters. done: 54 [Current cost: -0.66349716]
# Iters. done: 55 [Current cost: -0.6537321]
# Iters. done: 56 [Current cost: -0.6626848799999999]
# Iters. done: 57 [Current cost: -0.65363374]
# Iters. done: 58 [Current cost: -0.66411648]
# Iters. done: 59 [Current cost: -0.65961704]
# Iters. done: 60 [Current cost: -0.65347708]
# Iters. done: 61 [Current cost: -0.66953084]
# Iters. done: 62 [Current cost: -0.6677149]
# Iters. done: 63 [Current cost: -0.66597512]
# Iters. done: 64 [Current cost: -0.67500926]
# Iters. done: 65 [Current cost: -0.67203104]
# Iters. done: 66 [Current cost: -0.66095248]
# Iters. done: 67 [Current cost: -0.66640326]
# Iters. done: 68 [Current cost: -0.6668507800000001]
# Iters. done: 69 [Current cost: -0.670198]
# Iters. done: 70 [Current cost: -0.66487666]
# Iters. done: 71 [Current cost: -0.6669657000000001]
# Iters. done: 72 [Current cost: -0.6626787000000001]
# Iters. done: 73 [Current cost: -0.6704556400000001]
# Iters. done: 74 [Current cost: -0.66177132]
# Iters. done: 75 [Current cost: -0.6613722200000001]
# Iters. done: 76 [Current cost: -0.6645335600000001]
# Iters. done: 77 [Current cost: -0.66736208]
# Iters. done: 78 [Current cost: -0.66713668]
# Iters. done: 79 [Current cost: -0.6631867199999999]
# Iters. done: 80 [Current cost: -0.6617323800000001]
# Iters. done: 81 [Current cost: -0.66619236]
# Iters. done: 82 [Current cost: -0.67097224]
# Iters. done: 83 [Current cost: -0.6690773200000001]
# Iters. done: 84 [Current cost: -0.67069446]
# Iters. done: 85 [Current cost: -0.66687964]
# Iters. done: 86 [Current cost: -0.66301264]
# Iters. done: 87 [Current cost: -0.66172872]
# Iters. done: 88 [Current cost: -0.66558852]
# Iters. done: 89 [Current cost: -0.6724178999999999]
# Iters. done: 90 [Current cost: -0.66827488]
# Iters. done: 91 [Current cost: -0.66497592]
# Iters. done: 92 [Current cost: -0.66919216]
# Iters. done: 93 [Current cost: -0.66546322]
# Iters. done: 94 [Current cost: -0.66982786]
# Iters. done: 95 [Current cost: -0.6701651600000001]
# Iters. done: 96 [Current cost: -0.6688675599999999]
# Iters. done: 97 [Current cost: -0.66479454]
# Iters. done: 98 [Current cost: -0.6604521400000001]
# Iters. done: 99 [Current cost: -0.67023144]
# Iters. done: 100 [Current cost: -0.6689172800000001]
# Iters. done: 101 [Current cost: -0.66732332]
# Iters. done: 102 [Current cost: -0.6635303]
# Iters. done: 103 [Current cost: -0.66651518]
# Iters. done: 104 [Current cost: -0.6617069]
# Iters. done: 105 [Current cost: -0.6591793]
# Iters. done: 106 [Current cost: -0.66267926]
# Iters. done: 107 [Current cost: -0.66227276]
# Iters. done: 108 [Current cost: -0.6661285000000001]
# Iters. done: 109 [Current cost: -0.6610323400000001]
# Iters. done: 110 [Current cost: -0.6614331]
# Iters. done: 111 [Current cost: -0.664855]
# Iters. done: 112 [Current cost: -0.66310852]
# Iters. done: 113 [Current cost: -0.65574826]
# Iters. done: 114 [Current cost: -0.66516366]
# Iters. done: 115 [Current cost: -0.6623117800000001]
# Iters. done: 116 [Current cost: -0.66520828]
# Iters. done: 117 [Current cost: -0.6658137199999999]
# Iters. done: 118 [Current cost: -0.66152044]
# Iters. done: 119 [Current cost: -0.6595058]
# Iters. done: 120 [Current cost: -0.66210004]
# Iters. done: 121 [Current cost: -0.67024536]
# Iters. done: 122 [Current cost: -0.6689607200000001]
# Iters. done: 123 [Current cost: -0.665668]
# Iters. done: 124 [Current cost: -0.66843162]
# Iters. done: 125 [Current cost: -0.65668448]
# Iters. done: 126 [Current cost: -0.65978524]
# Iters. done: 127 [Current cost: -0.6609038]
# Iters. done: 128 [Current cost: -0.66248868]
# Iters. done: 129 [Current cost: -0.6651346800000001]
# Iters. done: 130 [Current cost: -0.6672381]
# Iters. done: 131 [Current cost: -0.6625743000000001]
# Iters. done: 132 [Current cost: -0.66835396]
# Iters. done: 133 [Current cost: -0.6672923199999999]
# Iters. done: 134 [Current cost: -0.66657778]
# Iters. done: 135 [Current cost: -0.66197656]
# Iters. done: 136 [Current cost: -0.66350594]
# Iters. done: 137 [Current cost: -0.66009812]
# Iters. done: 138 [Current cost: -0.6780497400000001]
# Iters. done: 139 [Current cost: -0.6618610199999999]
# Iters. done: 140 [Current cost: -0.65968616]
# Iters. done: 141 [Current cost: -0.66177938]
# Iters. done: 142 [Current cost: -0.6619634]
# Iters. done: 143 [Current cost: -0.6656124]
# Iters. done: 144 [Current cost: -0.6629056799999999]
# Iters. done: 145 [Current cost: -0.65519976]
# Iters. done: 146 [Current cost: -0.66226346]
# Iters. done: 147 [Current cost: -0.6709831]
# Iters. done: 148 [Current cost: -0.6693315400000001]
# Iters. done: 149 [Current cost: -0.6570410200000001]
# Iters. done: 150 [Current cost: -0.6685310400000001]
# Iters. done: 151 [Current cost: -0.66170814]
# Iters. done: 152 [Current cost: -0.6702739600000001]
# Iters. done: 153 [Current cost: -0.66425516]
# {   'fun': np.float64(-0.6780497400000001),
#     'jac': None,
#     'nfev': np.int64(153),
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.85186479, -2.08051909,  0.44152976, -3.89790802,  3.2486863 ,
#        -0.23311326, -0.54550462,  1.97965009,  1.95645222,  0.1491133 ,
#        -3.07938278,  0.09650594,  3.32303457, -0.07681587, -2.97749163,
#         2.66343813])}

# %% [markdown]
# ## Understanding the Results
#
# The above result shows us:
# - `fun`: the final optimised cost.
# - `nfev`: the amount of function evaluations, i.e. evaluations of the  cost function.
# - `jac`: if a jacobian function was used (in this case we did not use one, and we used finite differences to evaluate the gradient).
# - `nit`: the number of iterations, i.e. the number of times the minimum was updated.
# - `njev`: the number of times the gradient was evaluated.
# - `x`: the final optimized parameters for our PQC.
#
# Let us now plot some results.

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %% [markdown]
# ## Looking at the Plot
#
# We can see the cost decreasing as the number of iterations increase. Now how do we confirm that we have achieved the minimum?
#
# For small problems we can compute the minimum by diagonalizing the Hamiltonian.

# %%
# Getting eigenvalues and eigenvectors from the hamiltonian
u, v = np.linalg.eigh(hamiltonian.to_matrix())

# Printing lowest eigenvalue
print(min(u))

# Updating plot
ax.axhline(y = min(u), color='orange', linestyle = '--')
fig
# Out:
# -0.702930394459531

# %% [markdown]
# # We can now see that the minimum is achieved!

# %% [markdown]
# ## Trying Different Optimizers
#
# Now try to experiment with changing the optimizer: you can find a list of them supported by `Qiskit` [here](https://qiskit-community.github.io/qiskit-algorithms/apidocs/qiskit_algorithms.optimizers.html).
#
# Gradient-based:
# - `L_BFGS_B`': second-order gradient descent method.
# - `SPSA`: a stochastic gradient descent method.
#
# Gradient-free:
# - `NELDER_MEAD`: simplex method.
# - `POWELL`: conjugate direction method.

# %%
# optimizer = <OPTIMIZER>()
#
# cost_history_dict = {"prev_vector": None, "iters": 0, "cost_history": []}
#
# estimator = Estimator(mode=backend)
# estimator.options.default_shots = 10000
#
# wrapped_cost_function = partial(cost_function, ansatz=ansatz_isa, hamiltonian=hamiltonian_isa, estimator=estimator)
# result = optimizer.minimize(fun=wrapped_cost_function, x0=x0)
#
# print(result)
#
# fig, ax = plt.subplots()
# ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
# ax.axhline(y = min(u), color='orange', linestyle = '--')
# ax.set_xlabel("Iterations")
# ax.set_ylabel("Cost")
# plt.draw()

# %% [markdown]
# ## Next
#
# You now have a working VQE, but on a two-qubit operator that was handed to you, with an ansatz chosen for convenience rather than for the problem. In `3_Ising.ipynb` we take a real many-body model, the transverse-field Ising chain, build an ansatz out of the Hamiltonian itself, and use the model's exact solution to see exactly where and why a variational calculation fails. In `4_Chemistry.ipynb` we build the hydrogen Hamiltonian from the electronic structure problem, reduce it to two qubits using its symmetries, and compute the dissociation curve of the molecule.
