# %%
import numpy as np

# Pre-defined ansatz circuit and operator class for Hamiltonian
from qiskit.circuit.library import efficient_su2
from qiskit.quantum_info import SparsePauliOp, Statevector

# optimizer imports
from qiskit_algorithms.optimizers import *

# Plotting functions
import matplotlib.pyplot as plt

from functools import partial

# Global dictionary
cost_history_dict = {
	"prev_vector": None,
	"iters": 0,
	"cost_history": [],
}

from qiskit_ibm_runtime import EstimatorV2 as Estimator

# We will run everything on a local simulator. To run on real hardware you would
# instead pick a backend from QiskitRuntimeService and wrap the calls in a Session.
from qiskit_aer import AerSimulator
backend = AerSimulator()

# %% [markdown]
# ## Hamiltonian
#
# Our next two components: the PQC and measurement strategy, may depend quite a bit on our Hamiltonian, and any constraints which we wish to satisfy (however for the sake of simplicity we will suppose that we have no extra constraints). However, for now we shall take statevector simulations, that is we assume that we have perfect information of the quantum state (we have access to its vector representation). Thus, we need not worry about the measurement technique yet. This is useful for prototyping your VQA, ensuring that everything works.
#
# We shall take a simplified $H_2$ model at $0.735$Å, which can be written in Qiskit as
#
# > **Note.** This operator is a toy: it has roughly the right coefficient magnitudes for hydrogen but it is not the molecular Hamiltonian, so its lowest eigenvalue is not a physical energy. We derive the real one in `3_Chemistry.ipynb`.

# %%
hamiltonian = SparsePauliOp.from_list(
    [("II", -0.332404), ("IZ", 0.397937), ("ZI", 0.397937), ("ZZ", 0.011280), ("XX", 0.180931)]
)

# %% [markdown]
# ## Parameterized quantum circuit
#
# Now let's proceed to use a simple two local ansatz, that is an ansatz which alternates between parameterized one-qubit gates, and (non-parameterized) two-qubit entangling gates

# %%
ansatz = efficient_su2(hamiltonian.num_qubits)
ansatz.draw("mpl", style="iqp")

# %% [markdown]
# ## Preparing for Quantum Execution
#
# To reduce the total job execution time, Qiskit primitives only accept circuits (ansatz) and observables (Hamiltonian) that conform to the instructions and connectivity supported by the target system (referred to as instruction set architecture (ISA) circuits and observables).
#
# ISA circuit Schedule a series of `qiskit.transpiler` passes to optimize the circuit for a selected backend and make it compatible with the backend's ISA. This can be easily done with a preset pass manager from `qiskit.transpiler` and its `optimization_level` parameter.
#
# The lowest optimization level does the minimum needed to get the circuit running on the device; it maps the circuit qubits to the device qubits and adds swap gates to allow all two-qubit operations. The highest optimization level is much smarter and uses lots of tricks to reduce the overall gate count. Since multi-qubit gates have high error rates and qubits decohere over time, the shorter circuits should give better results.

# %%
# In principle, this code is not needed unless we intend to run it on a quantum device
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager

target = backend.target
pm = generate_preset_pass_manager(target=target, optimization_level=3)

ansatz_isa = pm.run(ansatz)

# %% [markdown]
# ## ISA observable
#
# Transform the Hamiltonian to make it backend-compatible before running jobs with `Runtime Estimator V2`. Perform the transformation by using the apply_layout method of SparsePauliOp object.

# %%
hamiltonian_isa = hamiltonian.apply_layout(layout=ansatz_isa.layout)

# %% [markdown]
# $$\newcommand{\ket}[1]{\left|{#1}\right\rangle}$$
# $$\newcommand{\bra}[1]{\left\langle{#1}\right|}$$
#
# # Variational Quantum Eigensolver
#
# The VQE is the first type of hybrid quantum--classical which was proposed, and it is the first one we will deal with. The cost function in this case based on the Ritz variational principle, that is
#
# \begin{equation}
#     C(\boldsymbol{\theta}) = \bra{\psi(\boldsymbol{\theta})}\mathcal{H}\ket{\psi(\boldsymbol{\theta})}.
# \end{equation}
#
# The minimum of this function is the ground-state energy:
#
# \begin{equation}
#     E_0 = \min_{\boldsymbol{\theta}}\bra{\psi(\boldsymbol{\theta})}\mathcal{H}\ket{\psi(\boldsymbol{\theta})}.
# \end{equation}
#
# We thus have the first component of our VQA, the cost function.
#
# With the Qiskit Runtime `Estimator` directly taking a Hamiltonian and parameterized ansatz, and returning the necessary energy, the cost function for a VQE instance is quite simple.
#
# Note that the `run()` method of Qiskit Runtime `EstimatorV2` takes an iterable of `primitive unified blocs (PUBs)`. Each PUB is an iterable in the format `(circuit, observables, parameter_values: Optional, precision: Optional)`.

# %%
def cost_function(params, ansatz, hamiltonian, estimator):
	pub = (ansatz, [hamiltonian], [params])
	result = estimator.run(pubs=[pub]).result()
	energy = result[0].data.evs[0]
	
	cost_history_dict["iters"] += 1
	cost_history_dict["prev_vector"] = params
	cost_history_dict["cost_history"].append(energy)
	print(f"Iters. done: {cost_history_dict['iters']} [Current cost: {energy}]")
	
	return energy

# %% [markdown]
# ## Classical optimizer
#
# As we said, for now shall focus on statevector simulations and not worry about measurements. The next step is then choose a classical optimizer. Qiskit has many optimizers to choose from. Quite a bit of them are based on Scipy's implementations. We will take the COBYLA optimizer for the time being.

# %%
optimizer = COBYLA()

# %% [markdown]
# ## Putting it all together
#
# We now just need to run the algorithm optimizing through to get our ground-state energy

# %%
x0 = np.random.uniform(-np.pi, np.pi, len(ansatz.parameters))  # We need an initial point (which can be random)

estimator = Estimator(mode=backend)
estimator.options.default_shots = 10000

wrapped_cost_function = partial(cost_function, ansatz=ansatz_isa, hamiltonian=hamiltonian_isa, estimator=estimator)
result = optimizer.minimize(fun=wrapped_cost_function, x0=x0)

print(result)
# Out:
# Iters. done: 1 [Current cost: -0.48101870859999996]
# Iters. done: 2 [Current cost: -0.34953077079999995]
# Iters. done: 3 [Current cost: -0.2476041878]
# Iters. done: 4 [Current cost: -0.4854509358]
# Iters. done: 5 [Current cost: -0.5950602032]
# Iters. done: 6 [Current cost: -0.4237078144]
# Iters. done: 7 [Current cost: -0.6014767882]
# Iters. done: 8 [Current cost: -0.5146234317999999]
# Iters. done: 9 [Current cost: -0.39362493879999993]
# Iters. done: 10 [Current cost: -0.45315669419999993]
# Iters. done: 11 [Current cost: -0.6675424179999999]
# Iters. done: 12 [Current cost: -0.6159485224]
# Iters. done: 13 [Current cost: -0.539137828]
# Iters. done: 14 [Current cost: -0.9201521312000001]
# Iters. done: 15 [Current cost: -0.8709869852000001]
# Iters. done: 16 [Current cost: -0.9089446883999999]
# Iters. done: 17 [Current cost: -0.9556369447999999]
# Iters. done: 18 [Current cost: -0.9525774564]
# Iters. done: 19 [Current cost: -0.8762815636000001]
# Iters. done: 20 [Current cost: -1.0216815832]
# Iters. done: 21 [Current cost: -0.951042662]
# Iters. done: 22 [Current cost: -0.9752099891999999]
# Iters. done: 23 [Current cost: -0.8064536479999999]
# Iters. done: 24 [Current cost: -0.9267493102]
# Iters. done: 25 [Current cost: -0.6967739704]
# Iters. done: 26 [Current cost: -0.9752422802]
# Iters. done: 27 [Current cost: -0.7380401424]
# Iters. done: 28 [Current cost: -1.0076956502]
# Iters. done: 29 [Current cost: -1.0330472004]
# Iters. done: 30 [Current cost: -0.9402743953999998]
# Iters. done: 31 [Current cost: -0.9572034904]
# Iters. done: 32 [Current cost: -0.9164813110000001]
# Iters. done: 33 [Current cost: -1.0087732778]
# Iters. done: 34 [Current cost: -0.8692309366]
# Iters. done: 35 [Current cost: -1.0291109204]
# Iters. done: 36 [Current cost: -0.8409715757999999]
# Iters. done: 37 [Current cost: -1.0584110104]
# Iters. done: 38 [Current cost: -0.9582956577999998]
# Iters. done: 39 [Current cost: -1.000371117]
# Iters. done: 40 [Current cost: -1.0799252192]
# Iters. done: 41 [Current cost: -1.0760218685999998]
# Iters. done: 42 [Current cost: -1.0860142512]
# Iters. done: 43 [Current cost: -1.0920225614]
# Iters. done: 44 [Current cost: -1.1035098286]
# Iters. done: 45 [Current cost: -1.095044797]
# Iters. done: 46 [Current cost: -1.1019944256]
# Iters. done: 47 [Current cost: -1.0960887006]
# Iters. done: 48 [Current cost: -1.0928157662]
# Iters. done: 49 [Current cost: -1.1075670296]
# Iters. done: 50 [Current cost: -1.1268829484]
# Iters. done: 51 [Current cost: -1.1330334966]
# Iters. done: 52 [Current cost: -1.1332845274]
# Iters. done: 53 [Current cost: -1.1285384165999999]
# Iters. done: 54 [Current cost: -1.1291002352]
# Iters. done: 55 [Current cost: -1.1272874942]
# Iters. done: 56 [Current cost: -1.1297977877999998]
# Iters. done: 57 [Current cost: -1.1316383272000001]
# Iters. done: 58 [Current cost: -1.133096226]
# Iters. done: 59 [Current cost: -1.1337525432]
# Iters. done: 60 [Current cost: -1.1299953396]
# Iters. done: 61 [Current cost: -1.1361554383999999]
# Iters. done: 62 [Current cost: -1.1358444636]
# Iters. done: 63 [Current cost: -1.1365496484]
# Iters. done: 64 [Current cost: -1.1356208546]
# Iters. done: 65 [Current cost: -1.1353615726]
# Iters. done: 66 [Current cost: -1.1401594646]
# Iters. done: 67 [Current cost: -1.1360943118]
# Iters. done: 68 [Current cost: -1.1328009293999999]
# Iters. done: 69 [Current cost: -1.1401770634]
# Iters. done: 70 [Current cost: -1.131919854]
# Iters. done: 71 [Current cost: -1.1330338088]
# Iters. done: 72 [Current cost: -1.1345004255999998]
# Iters. done: 73 [Current cost: -1.1362108704]
# Iters. done: 74 [Current cost: -1.130120909]
# Iters. done: 75 [Current cost: -1.1379391496]
# Iters. done: 76 [Current cost: -1.1325142981999998]
# Iters. done: 77 [Current cost: -1.1298489762]
# Iters. done: 78 [Current cost: -1.1313151438]
# Iters. done: 79 [Current cost: -1.1401676826]
# Iters. done: 80 [Current cost: -1.132015951]
# Iters. done: 81 [Current cost: -1.1320862294]
# Iters. done: 82 [Current cost: -1.1368435421999998]
# Iters. done: 83 [Current cost: -1.1385000764]
# Iters. done: 84 [Current cost: -1.1321549794]
# Iters. done: 85 [Current cost: -1.1305015807999999]
# Iters. done: 86 [Current cost: -1.136523149]
# Iters. done: 87 [Current cost: -1.135958373]
# Iters. done: 88 [Current cost: -1.1320849741999999]
# Iters. done: 89 [Current cost: -1.1399319801999999]
# Iters. done: 90 [Current cost: -1.132160163]
# Iters. done: 91 [Current cost: -1.1299543616]
# Iters. done: 92 [Current cost: -1.1392948339999998]
# Iters. done: 93 [Current cost: -1.13948783]
# Iters. done: 94 [Current cost: -1.133935207]
# Iters. done: 95 [Current cost: -1.1357828502]
# Iters. done: 96 [Current cost: -1.133899688]
# Iters. done: 97 [Current cost: -1.140147622]
# Iters. done: 98 [Current cost: -1.1362173026]
# Iters. done: 99 [Current cost: -1.1300495229999998]
# Iters. done: 100 [Current cost: -1.1391050992]
# Iters. done: 101 [Current cost: -1.1329250321999997]
# Iters. done: 102 [Current cost: -1.1323419814]
# Iters. done: 103 [Current cost: -1.1330005778]
# Iters. done: 104 [Current cost: -1.1343638108]
# Iters. done: 105 [Current cost: -1.1361213926]
# Iters. done: 106 [Current cost: -1.1343528666]
# Iters. done: 107 [Current cost: -1.1359060634]
# Iters. done: 108 [Current cost: -1.131075601]
# Iters. done: 109 [Current cost: -1.136903147]
# Iters. done: 110 [Current cost: -1.1357937944]
# Iters. done: 111 [Current cost: -1.138051771]
# Iters. done: 112 [Current cost: -1.1332431572]
# Iters. done: 113 [Current cost: -1.1346360584]
# Iters. done: 114 [Current cost: -1.1346012131999998]
# Iters. done: 115 [Current cost: -1.1384991845999999]
# Iters. done: 116 [Current cost: -1.1337538268]
# Iters. done: 117 [Current cost: -1.1358140774]
# Iters. done: 118 [Current cost: -1.1363943029999999]
# Iters. done: 119 [Current cost: -1.1384360586]
# Iters. done: 120 [Current cost: -1.1376908008]
# Iters. done: 121 [Current cost: -1.1318529821999999]
# Iters. done: 122 [Current cost: -1.1346206022]
# Iters. done: 123 [Current cost: -1.1374812343999998]
# Iters. done: 124 [Current cost: -1.131957249]
# Iters. done: 125 [Current cost: -1.1375839422]
# Iters. done: 126 [Current cost: -1.1368031675999999]
# Iters. done: 127 [Current cost: -1.1338734219999997]
# Iters. done: 128 [Current cost: -1.1370219848]
# Iters. done: 129 [Current cost: -1.139954767]
# Iters. done: 130 [Current cost: -1.1353098378]
# Iters. done: 131 [Current cost: -1.1339972166]
# Iters. done: 132 [Current cost: -1.1353039847999997]
# Iters. done: 133 [Current cost: -1.1359853149999999]
# Iters. done: 134 [Current cost: -1.1384675081999998]
# Iters. done: 135 [Current cost: -1.1334404384]
# Iters. done: 136 [Current cost: -1.1369632342]
# Iters. done: 137 [Current cost: -1.1334290472]
# Iters. done: 138 [Current cost: -1.1376593512]
# Iters. done: 139 [Current cost: -1.1338862907999998]
# Iters. done: 140 [Current cost: -1.13439942]
# Iters. done: 141 [Current cost: -1.1342525325999997]
# Iters. done: 142 [Current cost: -1.1373306388]
# Iters. done: 143 [Current cost: -1.1387712053999999]
# Iters. done: 144 [Current cost: -1.1406787134]
# Iters. done: 145 [Current cost: -1.1323931834]
# Iters. done: 146 [Current cost: -1.1399851859999999]
# Iters. done: 147 [Current cost: -1.1387666956]
# Iters. done: 148 [Current cost: -1.1364632842]
# Iters. done: 149 [Current cost: -1.1310024269999999]
# Iters. done: 150 [Current cost: -1.1366489518]
# Iters. done: 151 [Current cost: -1.1355172616]
# Iters. done: 152 [Current cost: -1.1348912863999998]
# Iters. done: 153 [Current cost: -1.1363041115999999]
# Iters. done: 154 [Current cost: -1.1324892322]
# Iters. done: 155 [Current cost: -1.1357279444000001]
# Iters. done: 156 [Current cost: -1.1367506289999998]
# Iters. done: 157 [Current cost: -1.140462041]
# Iters. done: 158 [Current cost: -1.1406727237999998]
# Iters. done: 159 [Current cost: -1.133035064]
# Iters. done: 160 [Current cost: -1.134603358]
# Iters. done: 161 [Current cost: -1.1328720466]
# Iters. done: 162 [Current cost: -1.136942284]
# Iters. done: 163 [Current cost: -1.1341094811999999]
# {   'fun': np.float64(-1.1406787134),
#     'jac': None,
#     'nfev': np.int64(163),
#     'nit': None,
#     'njev': None,
#     'x': array([ 0.83241926, -1.58476201,  1.56617993,  4.0381321 ,  0.0925039 ,
#         0.50358037, -2.30469028, -3.29740751, -2.6511856 ,  3.28868066,
#        -0.79397709, -2.29712326, -0.50160338, -1.37292033, -1.48107826,
#         1.31719624])}

# %% [markdown]
# ## Understanding the Results
#
# The above result shows us:
# - `fun`: the final optimised cost.
# - `nfev`: the amount of function evaluations, i.e. evaluations of the  cost function.
# - `jac`: if a jacobian function was used (in this case we did not use one, and we used finite differences to evaluate the gradient).
# - `nit`: the number of iterations, i.e. the number of times the minimum was updated.
# - `njev`: the number of times the gradient was evaluated.
# - `x`: the final optimized parameters for our PQC.
#
# Let us now plot some results.

# %%
fig, ax = plt.subplots()
ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
ax.set_xlabel("Iterations")
ax.set_ylabel("Cost")
plt.draw()

# %% [markdown]
# ## Looking at the Plot
#
# We can see the cost decreasing as the number of iterations increase. Now how do we confirm that we have achieved the minimum?
#
# For small problems we can compute the minimum by diagonalizing the Hamiltonian.

# %%
# Getting eigenvalues and eigenvectors from the hamiltonian
u, v = np.linalg.eigh(hamiltonian.to_matrix())

# Printing lowest eigenvalue
print(min(u))

# Updating plot
ax.axhline(y = min(u), color='orange', linestyle = '--')
fig
# Out:
# -1.1373050158518758

# %% [markdown]
# # We can now see that the minimum is achieved!

# %% [markdown]
# ## Trying Different Optimizers
#
# Now try to experiment with changing the optimizer: you can find a list of them supported by `Qiskit` [here](https://qiskit-community.github.io/qiskit-algorithms/apidocs/qiskit_algorithms.optimizers.html).
#
# Gradient-based:
# - `L_BFGS_B`': second-order gradient descent method.
# - `SPSA`: a stochastic gradient descent method.
#
# Gradient-free:
# - `NELDER_MEAD`: simplex method.
# - `POWELL`: conjugate direction method.

# %%
# optimizer = <OPTIMIZER>()
#
# cost_history_dict = {"prev_vector": None, "iters": 0, "cost_history": []}
#
# estimator = Estimator(mode=backend)
# estimator.options.default_shots = 10000
#
# wrapped_cost_function = partial(cost_function, ansatz=ansatz_isa, hamiltonian=hamiltonian_isa, estimator=estimator)
# result = optimizer.minimize(fun=wrapped_cost_function, x0=x0)
#
# print(result)
#
# fig, ax = plt.subplots()
# ax.plot(range(cost_history_dict["iters"]), cost_history_dict["cost_history"])
# ax.axhline(y = min(u), color='orange', linestyle = '--')
# ax.set_xlabel("Iterations")
# ax.set_ylabel("Cost")
# plt.draw()

# %% [markdown]
# ## Next
#
# You now have a working VQE, but on a two-qubit operator that was handed to you, with an ansatz chosen for convenience rather than for the problem. In `3_Ising.ipynb` we take a real many-body model, the transverse-field Ising chain, build an ansatz out of the Hamiltonian itself, and use the model's exact solution to see exactly where and why a variational calculation fails. In `4_Chemistry.ipynb` we build the hydrogen Hamiltonian from the electronic structure problem, reduce it to two qubits using its symmetries, and compute the dissociation curve of the molecule.
